# %% [markdown]
# #### Source
# - https://www.brianheinold.net/python/python_book.html#section_getting_input
# - https://en.wikibooks.org/wiki/A_Beginner%27s_Python_Tutorial
# - https://en.wikibooks.org/wiki/A_Beginner%27s_Python_Tutorial/Variables,_Scripts
# - https://allendowney.github.io/ThinkPython/chap01.html

# %%
# sample code
print("Hello, World!")

# %%
# getting user input
name = input("please enter your name: ")
print('Hello', name)

# %%
# sample input and calculation
num1 = int(input("Enter first number:"))
print('square of entered number:', num1*num1)
