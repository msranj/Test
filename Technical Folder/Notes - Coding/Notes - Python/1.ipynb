# %%
# sample code
print("Hello, World!")
# Out:
# Hello, World!

# %%
# getting user input
name = input("please enter your name: ")
print('Hello', name)
# Out:
# Hello abc

# %%
# sample input and calculation
num1 = int(input("Enter first number:"))
print('square of entered number:', num1*num1)
# Out:
# square of entered number: 25
